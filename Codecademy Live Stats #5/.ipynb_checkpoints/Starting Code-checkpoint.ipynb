# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import random

# %%
monthly_report = pd.read_csv('monthly_report.csv')

# %%
monthly_report.head()
# Out:
#              timestamp purchase                       item
# 0  2020-01-17 17:23:06        y  cue cards - love actually
# 1  2020-01-25 17:09:39        n                        NaN
# 2  2020-01-25 05:22:01        n                        NaN
# 3  2020-01-18 04:33:40        y      t-rex - jurassic park
# 4  2020-01-24 17:24:52        n                        NaN

# %%
np.sum(monthly_report.purchase == 'y')
# Out:
# 41

# %%
len(monthly_report[monthly_report.purchase == 'y'])
# Out:
# 41

# %%
monthly_report['purchase'].value_counts(normalize=True)
# Out:
# n    0.918
# y    0.082
# Name: purchase, dtype: float64

# %%
# concept of binomal distribution .. the more flips the close it gets to 50%
flips = np.random.choice(['heads','tails'], size = 5000, p=[.5,.5])
num_heads = np.sum(flips == 'heads')
print(num_heads)
# Out:
# 2500

# %%
simulated_visitors = np.random.choice(['y','n'], size = 500, p=[.1,.9])
purchases = np.sum(simulated_visitors == 'y')
print(purchases)
# Out:
# 45

# %%
null_purchases = []
for i in range (10000):
    simulated_visitors = np.random.choice(['y','n'], size = 500, p=[.1,.9])
    purchases = np.sum(simulated_visitors == 'y')
    null_purchases.append(purchases)

# %%
plt.hist(null_purchases)
plt.axvline(41, color='r')
plt.show()

# %%
# null hypothesis: probability of purchase is 10%
# alternative hypothesis: probability of purchase is < 10%

# In null hypothesis significance testing, the p-value is the probability of obtaining test results at least as extreme as the results actually observed, under the assumption that the null hypothesis is correct.[2][3] A very small p-value means that such an extreme observed outcome would be very unlikely under the null hypothesis. Reporting p-values of statistical tests is common practice in academic publications of many quantitative fields. Since the precise meaning of p-value is hard to grasp, misuse is widespread and has been a major topic in metascience.

# %%
# p value, what is the probablity that 
p_value = np.sum(np.array(null_purchases) <= 41)/len(null_purchases)
print(p_value)
# Out:
# 0.101

# %%
from scipy.stats import binom_test
p_value_scipy = binom_test(41, 500, .1, alternative='less')
print(p_value_scipy)
# Out:
# 0.1001135269756488
